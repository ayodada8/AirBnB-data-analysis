# %% [markdown]
# # AirBnB NY
# ### This project analyses the airbnb data in 2019 from new york united states.

# %%
# import libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# import data as data
data = pd.read_csv('AB_NYC_2019.csv')

# %%
# Check data head
data.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
# Check data info
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %% [markdown]
# #### The columns are in fairly good conditions already so we can explore the data
# # Data Exploration

# %%
# Check for null rows
data.isna().sum().sort_values(ascending = False)
# Out:
# last_review                       10052
# reviews_per_month                 10052
# host_name                            21
# name                                 16
# id                                    0
# host_id                               0
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
# Lets explore the host_name and host_id, lets see if we can fill the missing values
data['host_name'].nunique()
# Out:
# 11452

# %%
data['host_id'].nunique()
# Out:
# 37457

# %%
data['host_name'].value_counts()
# Out:
# Michael              417
# David                403
# Sonder (NYC)         327
# John                 294
# Alex                 279
#                     ...
# Rhonycs                1
# Brandy-Courtney        1
# Shanthony              1
# Aurore And Jamila      1
# Ilgar & Aysel          1
# Name: host_name, Length: 11452, dtype: int64

# %%
data['host_id'].value_counts()
# Out:
# 219517861    327
# 107434423    232
# 30283594     121
# 137358866    103
# 16098958      96
#             ...
# 23727216       1
# 89211125       1
# 19928013       1
# 1017772        1
# 68119814       1
# Name: host_id, Length: 37457, dtype: int64

# %%
# Lets check the missing host_name ids
data[data['host_name'].isnull()]
# Out:
#              id                                               name    host_id  \
# 360      100184                                          Bienvenue     526653
# 2700    1449546                            Cozy Studio in Flatbush    7779204
# 5745    4183989    SPRING in the City!! Zen-Style Tranquil Bedroom     919218
# 6075    4446862                 Charming Room in Prospect Heights!   23077718
# 6582    4763327                Luxurious, best location, spa inc'l   24576978
# 8163    6292866                          Modern Quiet Gem Near All   32722063
# 8257    6360224                    Sunny, Private room in Bushwick   33134899
# 8852    6786181                       R&S Modern Spacious Hideaway   32722063
# 9138    6992973                    1 Bedroom in Prime Williamsburg    5162530
# 9817    7556587                               Sunny Room in Harlem   39608626
# 14040  10709846                 Sunny, spacious room in Greenpoint    7822683
# ...

# %% [markdown]
# ### Its obvious we cant fill in the host name from various analysis, we dont necessarily need the name, we have the ids, we can also do our analysis and prediction without the missing columns.

# %%
data.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
# Lets view the price column since its our target
plt.figure(figsize=(12,10))
sns.histplot(data['price'])
# Out:
# <AxesSubplot:xlabel='price', ylabel='Count'>

# %%
# we can see there are some outlier values not allowing proper visualization, lets check and drop them for this plot
data['price'].sort_values(ascending= False)
# Out:
# 9151     10000
# 17692    10000
# 29238    10000
# 40433     9999
# 12342     9999
#          ...
# 25778        0
# 25796        0
# 25433        0
# 26841        0
# 25795        0
# Name: price, Length: 48895, dtype: int64

# %%
# Dropping top 1% and plotting
len(data['price']) - (len(data['price']) - (len(data['price']) * 0.01))
# Out:
# 488.9499999999971

# %%
price_cropped = data['price'].sort_values(ascending= False)[488 : ]
price_cropped.sort_values(ascending= False)
# Out:
# 20108    799
# 43211    799
# 19135    799
# 19122    799
# 31944    795
#         ...
# 23161      0
# 25634      0
# 26866      0
# 25753      0
# 25795      0
# Name: price, Length: 48407, dtype: int64

# %%
# Lets view the cropped price column
plt.figure(figsize=(12,10))
sns.histplot(price_cropped, bins=40)
# Out:
# <AxesSubplot:xlabel='price', ylabel='Count'>

# %% [markdown]
# ### Most of the house prices are around 40 to 80 dollars

# %%
data.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
# visualize the room types 
plt.figure(figsize = (10,8))
sns.countplot(data['room_type'].sort_values(ascending= False))
plt.show()
# Out:
# C:\Users\Ayo\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ### There are only 3 room types in this data set with the shared room type very few compared to the two other types

# %%
# Check the neigbourhood group and neigbourhood
plt.figure(figsize = (10,8))
sns.countplot(data['neighbourhood_group'], order= data['neighbourhood_group'].value_counts().index)
plt.show()
# Out:
# C:\Users\Ayo\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ### Manhattan has the most houses followed by brooklyn

# %%
# Map of the loacations according to neigbourhood groupings
plt.figure(figsize=(10,6))
sns.scatterplot(data = data, x = 'longitude' ,y = 'latitude', hue= 'neighbourhood_group')
plt.show()

# %%
# The top 3 most expensive houses
data.sort_values(by='price', ascending=False)[:3]
# Out:
#              id                                             name   host_id  \
# 9151    7003697              Furnished room in Astoria apartment  20582832
# 17692  13894339  Luxury 1 bedroom apt. -stunning Manhattan views   5143901
# 29238  22436899                              1-BR Lincoln Center  72390391
#
#       host_name neighbourhood_group    neighbourhood  latitude  longitude  \
# 9151   Kathrine              Queens          Astoria  40.76810  -73.91651
# 17692      Erin            Brooklyn       Greenpoint  40.73260  -73.95739
# 29238    Jelena           Manhattan  Upper West Side  40.77213  -73.98665
#
#              room_type  price  minimum_nights  number_of_reviews last_review  \
# 9151      Private room  10000             100                  2  2016-02-13
# 17692  Entire home/apt  10000               5                  5  2017-07-27
# 29238  Entire home/apt  10000              30                  0         NaN
#
# ...

# %% [markdown]
# ### The top 3 most expensive houses cost 10000

# %%
# The 3 least expensive houses
data.sort_values(by='price', ascending=True)[:3]
# Out:
#              id                                             name    host_id  \
# 25796  20639914     Cozy yet spacious private brownstone bedroom   86327101
# 25634  20523843  MARTIAL LOFT 3: REDEMPTION (upstairs, 2nd room)   15787004
# 25433  20333471    ★Hostel Style Room | Ideal Traveling Buddies★  131697576
#
#           host_name neighbourhood_group       neighbourhood  latitude  \
# 25796       Adeyemi            Brooklyn  Bedford-Stuyvesant  40.68258
# 25634  Martial Loft            Brooklyn            Bushwick  40.69467
# 25433        Anisha               Bronx     East Morrisania  40.83296
#
#        longitude     room_type  price  minimum_nights  number_of_reviews  \
# 25796  -73.91284  Private room      0               1                 95
# 25634  -73.92433  Private room      0               2                 16
# 25433  -73.88668  Private room      0               2                 55
#
#       last_review  reviews_per_month  calculated_host_listings_count  \
# ...

# %% [markdown]
# ### Seems some of the houses were given out for free with a price of 0

# %% [markdown]
# ### Those are some of the few possible insights we could draw from this data.
